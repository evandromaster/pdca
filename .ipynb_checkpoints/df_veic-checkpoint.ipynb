# %%
# %run -i funcs.py
import pandas  as pd
# import funcs
# from funcs import var

# %%
df_ocorrencias,df_armas_fgo,df_envolvidos,df_veiculos,df_materiais,df_infracoes,df_integrantes = read_sheets()
columns()
df_veiculos.columns
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Index(['NÚMERO_REDS', 'ÓRGÃO_UNIDADE_REGISTRO', 'UNIDADE_ÁREA_MILITAR',
#        'UNID_REGISTRO_NÍVEL_6', 'CÓDIGO_SUBCLASSE_NAT_PRINCIPAL',
#        'TENTADO/CONSUMADO_NAT_PRINCIPAL', 'DATA_FATO', 'HORÁRIO_FATO',
#        'MUNICÍPIO', 'SITUAÇÃO_VEÍCULO', 'TIPO_VEÍCULO', 'ANO_MODELO',
#        'MARCA_/_MODELO', 'QTDE_VEÍCULOS'],
#       dtype='object')

# %%
sit_veic = ('APREENDIDO', 'RECUPERADO')
df_veiculos = df_veiculos.loc[df_veiculos['SITUAÇÃO_VEÍCULO'].isin(sit_veic)]

df_veiculos
# Out:
#             NÚMERO_REDS ÓRGÃO_UNIDADE_REGISTRO           UNIDADE_ÁREA_MILITAR  \
# 0    2020-031421003-001        POLICIA MILITAR  2 PEL/290 CIA PM/63 BPM/7 RPM
# 1    2020-031421003-001        POLICIA MILITAR  2 PEL/290 CIA PM/63 BPM/7 RPM
# 2    2020-031445121-001        POLICIA MILITAR         51 CIA PM/23 BPM/7 RPM
# 4    2020-031450782-001        POLICIA MILITAR         51 CIA PM/23 BPM/7 RPM
# 6    2020-031456686-001        POLICIA MILITAR         51 CIA PM/23 BPM/7 RPM
# ..                  ...                    ...                            ...
# 765  2020-036270630-001        POLICIA MILITAR      4 PEL/19 CIA PM IND/7 RPM
# 766  2020-036277397-001        POLICIA MILITAR      3 PEL/19 CIA PM IND/7 RPM
# 767  2020-036278978-001        POLICIA MILITAR                       INVÁLIDO
# 769  2020-036317020-001        POLICIA MILITAR                       INVÁLIDO
# 770  2020-036336986-001        POLICIA MILITAR         53 CIA PM/23 BPM/7 RPM
#
#        UNID_REGISTRO_NÍVEL_6 CÓDIGO_SUBCLASSE_NAT_PRINCIPAL  \
# 0               63 BPM/7 RPM                         T00008
# 1               63 BPM/7 RPM                         T00008
# 2     51 CIA PM/23 BPM/7 RPM                         T10161
# 4     51 CIA PM/23 BPM/7 RPM                         T10161
# 6     51 CIA PM/23 BPM/7 RPM                         T10161
# ..                       ...                            ...
# 765      19 CIA PM IND/7 RPM                         T00009
# 766      19 CIA PM IND/7 RPM                         T10161
# 767  142 CIA PM/23 BPM/7 RPM                         C01157
# 769  142 CIA PM/23 BPM/7 RPM                         A16000
# 770  240 CIA TM/23 BPM/7 RPM                         T10161
#
#     TENTADO/CONSUMADO_NAT_PRINCIPAL  DATA_FATO HORÁRIO_FATO      MUNICÍPIO  \
# 0                         CONSUMADO 2020-07-01     00:32:29        FORMIGA
# 1                         CONSUMADO 2020-07-01     00:32:29        FORMIGA
# 2                         CONSUMADO 2020-07-01     08:38:07         ITAUNA
# 4                         CONSUMADO 2020-07-01     09:18:50         ITAUNA
# 6                         CONSUMADO 2020-07-01     10:00:07         ITAUNA
# ..                              ...        ...          ...            ...
# 765                       CONSUMADO 2020-07-28     19:30:00      PAPAGAIOS
# 766                       CONSUMADO 2020-07-28     22:11:51  PARA DE MINAS
# 767                       CONSUMADO 2020-07-28     21:38:49    DIVINOPOLIS
# 769                       CONSUMADO 2020-07-29     07:05:38    DIVINOPOLIS
# 770                       CONSUMADO 2020-07-29     10:47:06    DIVINOPOLIS
#
#     SITUAÇÃO_VEÍCULO TIPO_VEÍCULO  ANO_MODELO            MARCA_/_MODELO  \
# 0         APREENDIDO    AUTOMOVEL         NaN      CHEVROLET/CLASSIC LS
# 1         APREENDIDO  MOTOCICLETA         NaN             HONDA/CB 300R
# 2         APREENDIDO    AUTOMOVEL      2017.0     MMC/L200 TRITON GLX D
# 4         APREENDIDO    AUTOMOVEL      2011.0   FIAT/UNO MILLE WAY ECON
# 6         APREENDIDO    AUTOMOVEL      2000.0            VW/GOL SPECIAL
# ..               ...          ...         ...                       ...
# 765       APREENDIDO    AUTOMOVEL         NaN             FIAT/PALIO EX
# 766       APREENDIDO  MOTOCICLETA      2003.0           YAMAHA/XTZ 125K
# 767       RECUPERADO    AUTOMOVEL      2005.0  FIAT/PALIO WK ADVEN FLEX
# 769       RECUPERADO    AUTOMOVEL      2012.0          FIAT/UNO WAY 1.0
# 770       APREENDIDO    AUTOMOVEL      2007.0   GM/VECTRA SD EXPRESSION
#
#      QTDE_VEÍCULOS
# 0                1
# 1                1
# 2                1
# 4                1
# 6                1
# ..             ...
# 765              1
# 766              1
# 767              1
# 769              1
# 770              1
#
# [623 rows x 14 columns]

# %%
df_veiculos
# Out:
#             NÚMERO_REDS ÓRGÃO_UNIDADE_REGISTRO           UNIDADE_ÁREA_MILITAR  \
# 0    2020-031421003-001        POLICIA MILITAR  2 PEL/290 CIA PM/63 BPM/7 RPM
# 1    2020-031421003-001        POLICIA MILITAR  2 PEL/290 CIA PM/63 BPM/7 RPM
# 2    2020-031445121-001        POLICIA MILITAR         51 CIA PM/23 BPM/7 RPM
# 3    2020-031445777-001        POLICIA MILITAR        142 CIA PM/23 BPM/7 RPM
# 4    2020-031450782-001        POLICIA MILITAR         51 CIA PM/23 BPM/7 RPM
# ..                  ...                    ...                            ...
# 767  2020-036278978-001        POLICIA MILITAR                       INVÁLIDO
# 768  2020-036285036-001        POLICIA MILITAR                   60 BPM/7 RPM
# 769  2020-036317020-001        POLICIA MILITAR                       INVÁLIDO
# 770  2020-036336986-001        POLICIA MILITAR         53 CIA PM/23 BPM/7 RPM
# 771  2020-036376988-001        POLICIA MILITAR         51 CIA PM/23 BPM/7 RPM
#
#              UNID_REGISTRO_NÍVEL_6 CÓDIGO_SUBCLASSE_NAT_PRINCIPAL  \
# 0                     63 BPM/7 RPM                         T00008
# 1                     63 BPM/7 RPM                         T00008
# 2           51 CIA PM/23 BPM/7 RPM                         T10161
# 3    7 CIA PM MAMB/BPM MAMB/CPMAMB                         U31999
# 4           51 CIA PM/23 BPM/7 RPM                         T10161
# ..                             ...                            ...
# 767        142 CIA PM/23 BPM/7 RPM                         C01157
# 768        279 CIA PM/60 BPM/7 RPM                         C01157
# 769        142 CIA PM/23 BPM/7 RPM                         A16000
# 770        240 CIA TM/23 BPM/7 RPM                         T10161
# 771         51 CIA PM/23 BPM/7 RPM                         C01157
#
#     TENTADO/CONSUMADO_NAT_PRINCIPAL  DATA_FATO HORÁRIO_FATO    MUNICÍPIO  \
# 0                         CONSUMADO 2020-07-01     00:32:29      FORMIGA
# 1                         CONSUMADO 2020-07-01     00:32:29      FORMIGA
# 2                         CONSUMADO 2020-07-01     08:38:07       ITAUNA
# 3                         CONSUMADO 2020-07-01     08:31:08  DIVINOPOLIS
# 4                         CONSUMADO 2020-07-01     09:18:50       ITAUNA
# ..                              ...        ...          ...          ...
# 767                       CONSUMADO 2020-07-28     21:38:49  DIVINOPOLIS
# 768                       CONSUMADO 2020-07-28     21:10:00     PERDIGAO
# 769                       CONSUMADO 2020-07-29     07:05:38  DIVINOPOLIS
# 770                       CONSUMADO 2020-07-29     10:47:06  DIVINOPOLIS
# 771                       CONSUMADO 2020-07-29     14:56:25       ITAUNA
#
#     SITUAÇÃO_VEÍCULO TIPO_VEÍCULO  ANO_MODELO            MARCA_/_MODELO  \
# 0         APREENDIDO    AUTOMOVEL         NaN      CHEVROLET/CLASSIC LS
# 1         APREENDIDO  MOTOCICLETA         NaN             HONDA/CB 300R
# 2         APREENDIDO    AUTOMOVEL      2017.0     MMC/L200 TRITON GLX D
# 3            FURTADO    AUTOMOVEL      2012.0          FIAT/UNO WAY 1.0
# 4         APREENDIDO    AUTOMOVEL      2011.0   FIAT/UNO MILLE WAY ECON
# ..               ...          ...         ...                       ...
# 767       RECUPERADO    AUTOMOVEL      2005.0  FIAT/PALIO WK ADVEN FLEX
# 768          ROUBADO  CAMINHONETE      2011.0   I/VW AMAROK CD 4X4 HIGH
# 769       RECUPERADO    AUTOMOVEL      2012.0          FIAT/UNO WAY 1.0
# 770       APREENDIDO    AUTOMOVEL      2007.0   GM/VECTRA SD EXPRESSION
# 771          ROUBADO    AUTOMOVEL      2018.0       FORD/KA SE 1.5 SD B
#
#      QTDE_VEÍCULOS
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# 767              1
# 768              1
# 769              1
# 770              1
# 771              1
#
# [772 rows x 14 columns]

# %%
pd.pivot_table(df_veiculos,
               index=['NÚMERO_REDS'], 
               values='QTDE_VEÍCULOS', 
               columns=['SITUAÇÃO_VEÍCULO'],
               fill_value=0,
               aggfunc=np.sum, 
               #margins=True, 
               #margins_name='Total Geral',
               #observed = True     

              ).reset_index()
# Out:
# SITUAÇÃO_VEÍCULO         NÚMERO_REDS  APREENDIDO  RECUPERADO
# 0                 2020-031421003-001           2           0
# 1                 2020-031445121-001           1           0
# 2                 2020-031450782-001           1           0
# 3                 2020-031456686-001           1           0
# 4                 2020-031457048-001           1           0
# ..                               ...         ...         ...
# 604               2020-036270630-001           1           0
# 605               2020-036277397-001           1           0
# 606               2020-036278978-001           0           1
# 607               2020-036317020-001           0           1
# 608               2020-036336986-001           1           0
#
# [609 rows x 3 columns]
